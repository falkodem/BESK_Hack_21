# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
SEED = 42

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
aggregates = pd.read_csv('aggregates.csv')
transactions = pd.read_csv('transactions.csv')

# %%
aggregates_help = pd.read_excel('aggregates.xlsx')
transactions_help = pd.read_excel('transactions.xlsx')

# %%
transactions_help
# Out:
#    Unnamed: 0         Атрибут           Описание атрибута
# 0           0       client_id  Замаскированный ID клиента
# 1           1  last_day_month               Отчетная дата
# 2           2       mcc_group                  Группа МСС
# 3           3         att_sum            Сумма транзакций
# 4           4         att_cnt       Количество транзакций
# 5           5     att_sum_min      Минимальная транзакция
# 6           6     att_sum_max     Максимальная транзакция
# 7           7     att_sum_avg          Средняя транзакция

# %% [markdown]
# # Взглянем на данные

# %%
aggregates_help['Описание атрибута']
# Out:
# 0                             Замаскированный ID клиента
# 1                                          Отчетная дата
# 2      количество зарплатных начислений, за последний...
# 3      количество зарплатных начислений, за последние...
# 4      количество зарплатных начислений, за последние...
#                              ...
# 215    общее число просрочек до 29 дней в банке за 5 лет
# 216    общее число просрочек от 30 до 59 дней в банке...
# 217    общее число просрочек от 60 до 89 дней в банке...
# 218    общее число просрочек от 90 до 119 дней в банк...
# 219    общее число просрочек от 120 дней в банке за 5...
# Name: Описание атрибута, Length: 220, dtype: object

# %%
aggregates_10 = aggregates.loc[:, (aggregates.isnull().mean() < 0.10)]

# %%
aggregates.select_dtypes(include=['object'])
# Out:
#                 report_date   app_rel_status     app_education_nm  \
# 0       2019-11-01 00:00:00              NaN                  NaN
# 1       2019-11-01 00:00:00              NaN                  NaN
# 2       2019-11-01 00:00:00              NaN                  NaN
# 3       2019-11-01 00:00:00  женат / замужем               Высшее
# 4       2019-11-01 00:00:00
# ...                     ...              ...                  ...
# 177958  2020-02-01 00:00:00              NaN                  NaN
# 177959  2020-02-01 00:00:00    Женат/Замужем  Среднее специальное
# 177960  2020-02-01 00:00:00
# 177961  2020-02-01 00:00:00              NaN                  NaN
# 177962  2020-02-01 00:00:00    Женат/Замужем               Высшее
#
#                 app_industry_nm  app_employment_type_nm  \
# 0                           NaN                     NaN
# 1                           NaN                     NaN
# 2                           NaN                     NaN
# 3                        Другое  Основная сфера деят-ти
# 4       ТЭК/ химия и нефтехимия                       0
# ...                         ...                     ...
# 177958                      NaN                     NaN
# 177959                                                0
# 177960  ТЭК/ химия и нефтехимия                       0
# 177961                      NaN                     NaN
# 177962                   Другое  Основная сфера деят-ти
#
#             app_position_type_nm  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3       не руководящий сотрудник
# 4
# ...                          ...
# 177958                       NaN
# 177959
# 177960
# 177961                       NaN
# 177962  не руководящий сотрудник
#
#                                       app_client_category             cre_date
# 0                                                     NaN                  NaN
# 1                                                     NaN                  NaN
# 2                                                     NaN                  NaN
# 3                         Клиенты розничного кредитования  2019-02-26 00:00:00
# 4       Сотрудники Группы ГПБ, Группы Газпром и сотруд...                  NaN
# ...                                                   ...                  ...
# 177958                                                NaN                  NaN
# 177959                             Прочие физические лица  2019-07-24 00:00:00
# 177960  Сотрудники Группы ГПБ, Группы Газпром и сотруд...  2017-02-08 00:00:00
# 177961                                                NaN                  NaN
# 177962                    Клиенты розничного кредитования                  NaN
#
# [177963 rows x 8 columns]

# %%
aggregates_help.values
# Out:
# array([[0, 'client_id', 'Замаскированный ID клиента'],
#        [1, 'report_date', 'Отчетная дата'],
#        [2, 'cnt_zp_1m',
#         'количество зарплатных начислений, за последний месяц'],
#        [3, 'cnt_zp_3m',
#         'количество зарплатных начислений, за последние 3 месяца'],
#        [4, 'cnt_zp_6m',
#         'количество зарплатных начислений, за последние 6 месяцев'],
#        [5, 'cnt_zp_12m',
#         'количество зарплатных поступлений за 12 месяцев'],
#        [6, 'downlimit_count', 'количество снижений кредитного лимита'],
#        [7, 'uplimit_count', 'количество увеличения кредитного лимита'],
#        [8, 'limit_exchange_count', 'общее количество изменений лимита'],
#        [9, 'cur_credit_limit', 'текущий установленный лимит'],
#        [10, 'cur_cr_lim_month',
#         'время в месяцах, прошедшее с установления текущего лимита'],
#        [11, 'prev_credit_limit', 'предыдущий лимит'],
#        [12, 'max_outstanding_amount_1m',
#         'максимальная задолженность по од за месяц'],
#        [13, 'max_outstanding_amount_3m',
#         'максимальная задолженность по од за 3 месяца'],
#        [14, 'max_outstanding_amount_6m',
#         'максимальная задолженность по од за 6 месяцев'],
#        [15, 'max_ovd_amount_1m',
#         'максимум просроченной задолженности за месяц'],
#        [16, 'max_ovd_amount_3m',
#         'максимум просроченной задолженности за 3 месяца'],
#        [17, 'max_ovd_amount_6m',
#         'максимум просроченной ссудной задолженности за 6 месяцев'],
#        [18, 'avg_outstanding_amount_1m',
#         'средняя задолженность по од за месяц'],
#        [19, 'avg_outstanding_amount_3m',
#         'средняя задолженность по од за 3 месяца'],
#        [20, 'avg_outstanding_amount_6m',
#         'средняя задолженность по од за 6 месяцев'],
#        [21, 'avg_ovd_amount_1m',
#         'средняя просроченная ссудная задолженность за месяц'],
#        [22, 'avg_ovd_amount_3m',
#         'средняя просроченная ссудная задолженность за 3 месяца'],
#        [23, 'avg_ovd_amount_6m',
#         'средняя просроченная ссудная задолженность за 6 месяцев'],
#        [24, 'max_utilization_1m',
#         'максимальная утилизация по карте за последний месяц'],
#        [25, 'max_utilization_3m',
#         'максимальная утилизация по карте за последние 3 месяца'],
#        [26, 'max_utilization_6m',
#         'максимальная утилизация по карте за последние 6 месяцев'],
#        [27, 'avg_utilization_1m',
#         'средняя утилизация по карте за последний месяц'],
#        [28, 'avg_utilization_3m',
#         'средняя утилизация по карте за последние 3 месяца'],
#        [29, 'avg_utilization_6m',
#         'средняя утилизация по карте за последние 6 месяцев'],
#        [30, 'avg_debt_3m',
#         'средняя сумма долга (од + просрочка) за последние 3 месяца'],
#        [31, 'avg_debt_6m',
#         'средняя сумма долга (од + просрочка) за последние 6 месяцев'],
#        [32, 'utilization',
#         'утилизация на дату расчета (на последнюю доступную дату)'],
#        [33, 'total_num_cards', 'общее количество счетов '],
#        [34, 'cnt_active', 'кол-во счетов со статусом "действующий"'],
#        [35, 'cnt_cur', 'количество счетов в иностранной валюте'],
#        [36, 'first_opened',
#         'время в месяцах, прошедшее с даты открытия самого раннего счёта'],
#        [37, 'last_opened',
#         'время в месяцах, прошедшее с даты открытия последнего счёта'],
#        [38, 'last6m_opened',
#         'количество счетов, открытых за последние 6 мес.'],
#        [39, 'last6m1y_opened',
#         'количество счетов, открытых от 6 до 12 мес. назад'],
#        [40, 'num_credit_cards', 'общее количество счетов кредитных карт'],
#        [41, 'num_debit_cards', 'общее количество счетов дебетовых карт'],
#        [42, 'num_prem_cards', 'общее количество золотых/платиновых карт'],
#        [43, 'extra_card_ind', 'наличие дополнительной карты'],
#        [44, 'actual_credit_card_flg',
#         'действующая кредитная карта, флаг'],
#        [45, 'cnt_dep_5y',
#         'количество срочных депозитов (т.е. имеющих срок, не "до востребования"), открытых за последние 5 лет'],
#        [46, 'cnt_dep_closed_5y',
#         'количество срочных депозитов, открытых за последние 5 лет, и закрытых на текущий момент'],
#        [47, 'cnt_dep_act',
#         'количество активных срочных депозитов, имеющих текущий остаток более 1000 р'],
#        [48, 'cnt_dep_6m',
#         'количество срочных депозитов (т.е. имеющих срок, не "до востребования"), открытых за последние 6 месяцев'],
#        [49, 'cnt_prolong_max',
#         'максимальное количество пролонгаций по всем срочным депозитам'],
#        [50, 'amt_min_prlg_max',
#         'минимальная (за весь период депозита) сумма срочного депозита, по которому было максимальное количество пролонгаций'],
#        [51, 'cnt_prolong_max_5y',
#         'максимальное количество пролонгаций по всем срочным депозитам, открытым в последние 5 лет'],
#        [52, 'amt_min_prlg_max_5y',
#         'минимальная сумма срочного депозита, открытого за последние 5 лет и по которому было максимальное количество пролонгаций'],
#        [53, 'cnt_foreign_cur_5y',
#         'количество срочных депозитов в иностранной валюте за последние 5 лет'],
#        [54, 'max_term_50_5y_closed',
#         'максимальный срок срочных депозитов более 50тр, открытых за последние 5 лет, и закрытых на текущий момент, в месяцах.'],
#        [55, 'max_term_50_5y_open',
#         'максимальный срок срочных депозитов более 50тр, открытых за последние 5 лет, и открытых на текущий момент, в месяцах.'],
#        [56, 'max_term_closed',
#         'максимальный срок срочных депозитов, закрытых на текущий момент'],
#        [57, 'max_term_open',
#         'максимальный срок срочных депозитов, открытых на текущий момент'],
#        [58, 'cnt_term_g1y_closed',
#         'количество срочных депозитов, открытых за последние 5 лет, и имеющие фактический срок больше года, закрытых на текущий момент'],
#        [59, 'cnt_term_g1y_open',
#         'количество срочных депозитов, открытых за последние 5 лет, и имеющие фактический срок больше года, открытых на текущий момент'],
#        [60, 'min_amt_term_g1y_closed',
#         'минимальная сумма срочных депозитов, открытых за последние 5 лет, и имеющие фактический срок больше года, закрытых на текущий момент'],
#        [61, 'min_amt_term_g1y_open',
#         'минимальная сумма срочных депозитов, открытых за последние 5 лет, и имеющие фактический срок больше года, открытых на текущий момент'],
#        [62, 'cnt_early_withdraw_5y',
#         'количество срочных депозитов, изъятых досрочно (среди открытых за последние 5 лет)'],
#        [63, 'cnt_account_5y',
#         'количество бессрочных депозитов ("до востребования") за последние 5 лет'],
#        [64, 'max_amt_dep_5y',
#         'максимальная сумма (при открытии, в рублях) срочных депозитов (т.е. имеющих срок, не "до востребования"), открытых за последние 5 лет'],
#        [65, 'max_amt_dep_closed_5y',
#         'максимальная сумма (при открытии, в рублях) срочных депозитов, открытых за последние 5 лет, и закрытых на текущий момент'],
#        [66, 'max_amt_dep_act',
#         'максимальная сумма (при открытии, в рублях) активных срочных депозитов, имеющих текущий остаток более 1000 р'],
#        [67, 'max_amt_dep_6m',
#         'максимальная сумма (при открытии, в рублях) срочных депозитов (т.е. имеющих срок, не "до востребования"), открытых за последние 6 месяцев'],
#        [68, 'max_amt_foreign_cur_5y',
#         'максимальная сумма (при открытии, в рублях) срочных депозитов в иностранной валюте за последние 5 лет'],
#        [69, 'sum_dep_now',
#         'текущая общая сумма (в рублях) срочных депозитов'],
#        [70, 'sum_acc_now',
#         'текущая общая сумма (в рублях) бессрочных депозитов ("до востребования")'],
#        [71, 'avg_sum_cls2op',
#         'среднее отношение суммы депозита при закрытии договора к сумме при открытии (только по срочным депозитам)'],
#        [72, 'avg_sum_nws2op',
#         'среднее отношение текущей суммы депозита к сумме при открытии (только по срочным депозитам)'],
#        [73, 'max_max_dep_balance',
#         'максимальный остаток за всю историю договора в рублях (максимальный по всем депозитам)'],
#        [74, 'min_max_dep_balance',
#         'максимальный остаток за всю историю договора в рублях (минимальный по всем депозитам)'],
#        [75, 'max_max_dep_income',
#         'максимальный приход за всю историю договора в рублях (максимальный по всем депозитам)'],
#        [76, 'sum_dep_income_1month',
#         'сумма прихода на депозиты за последний месяц'],
#        [77, 'avg_dep_avg_balance_1month',
#         'средний баланс по всем депозитам за последний месяц'],
#        [78, 'max_dep_avg_balance_1month',
#         'максимальный баланс по всем депозитам за последний месяц'],
#        [79, 'sum_dep_expense_1month',
#         'сумма расходных операций с депозитов за последний месяц'],
#        [80, 'sum_dep_income_3month',
#         'сумма прихода на депозиты за 3 месяца'],
#        [81, 'avg_dep_avg_balance_3month',
#         'средний баланс по всем депозитам за 3 месяца'],
#        [82, 'max_dep_avg_balance_3month',
#         'максимальный баланс по всем депозитам за 3 месяца'],
#        [83, 'sum_dep_expense_3month',
#         'сумма расходных операций с депозитов за 3 месяца'],
#        [84, 'sum_dep_income_6month',
#         'сумма прихода на депозиты за 6 месяцев'],
#        [85, 'sum_dep_expense_6month',
#         'сумма расходных операций с депозитов за 6 месяцев'],
#        [86, 'avg_dep_avg_balance_6month',
#         'средний баланс по всем депозитам за 6 месяцев'],
#        [87, 'max_dep_avg_balance_6month',
#         'максимальный баланс по всем депозитам за 6 месяцев'],
#        [88, 'avg_dep_avg_balance_12month',
#         'средний баланс по всем депозитам за 12 месяцев'],
#        [89, 'max_dep_avg_balance_12month',
#         'максимальный баланс по всем депозитам за 12 месяцев'],
#        [90, 'gender', 'пол клиента'],
#        [91, 'app_rel_status', 'семейное положение'],
#        [92, 'app_real_estate_ind', 'наличие недвижимости'],
#        [93, 'app_vehicle_ind', 'наличие авто'],
#        [94, 'app_education_nm', 'образование'],
#        [95, 'app_industry_nm', 'сфера деятельности'],
#        [96, 'app_employment_type_nm', 'тип занимаемой должности'],
#        [97, 'app_position_type_nm', 'уровень занимаемой позиции'],
#        [98, 'app_last_job_experience_from_val',
#         'нижняя граница опыта работы'],
#        [99, 'app_last_job_experience_to_val',
#         'верхняя граница опыта работы'],
#        [100, 'app_total_job_experience_val', 'общий стаж'],
#        [101, 'app_addresses_equal',
#         'адрес регистрации совпадает с адресом фактического проживания'],
#        [102, 'app_phone_home_flag', 'флаг наличия домашнего телефона'],
#        [103, 'app_client_category', 'категория клиента'],
#        [104, 'app_cc_cnt',
#         'количество заявок на кредитные/овердрафтные (с лимитом) карты в истории (по данным гпб)'],
#        [105, 'app_potreb_cnt',
#         'количество заявок на потребительские кредиты в истории (по данным гпб)'],
#        [106, 'app_mrtg_cnt',
#         'количество заявок на ипотеку в истории (по данным гпб)'],
#        [107, 'app_lst_request_m_term',
#         'количество месяцев с момента последней кредитной заявки'],
#        [108, 'app_lst_potreb_m_term',
#         'срок предыдущего потребительского кредита'],
#        [109, 'app_fst_request_m_term',
#         'количество месяцев с момента первой кредитной заявки'],
#        [110, 'sum_sal_acc_inc_6month_amt_rur',
#         'сумма зарплатных зачислений за последние 6 месяцев '],
#        [111, 'app_income_from_amt', 'доход клиента (нижний диапазон)'],
#        [112, 'app_income_to_amt', 'доход клиента (верхний диапазон)'],
#        [113, 'cnt_opened',
#         'количество открытых договоров, где обязательство имеет статус "открыто" (заёмщик)'],
#        [114, 'mrtg_open',
#         'количество открытых ипотечных кредитов (заёмщик)'],
#        [115, 'cl_open',
#         'количество открытых потребительских кредитов (заёмщик)'],
#        [116, 'auto_open', 'количество открытых автокредитов (заёмщик)'],
#        [117, 'card_open', 'количество открытых кредитных карт (заёмщик)'],
#        [118, 'micro_open', 'количество открытых микрозаймов (заёмщик)'],
#        [119, 'other_open',
#         'количество других открытых кредитов (не авто, не ипотека, не карта, не потребительский кредит) (заёмщик)'],
#        [120, 'cnt_opened_6m',
#         'определяется количество договоров, открытых не более полугода назад (заёмщик)'],
#        [121, 'cnt_opened_1y',
#         'определяется количество договоров, открытых не более года назад (заёмщик)'],
#        [122, 'cnt_closed',
#         'суммарное количество закрытых кредитов (заёмщик)'],
#        [123, 'mrtg_closed',
#         'количество закрытых ипотечных кредитов (заёмщик)'],
#        [124, 'cl_closed',
#         'количество закрытых потребительских кредитов (заёмщик)'],
#        [125, 'auto_closed', 'количество закрытых автокредитов (заёмщик)'],
#        [126, 'card_closed',
#         'количество закрытых кредитных карт (заёмщик)'],
#        [127, 'micro_closed', 'количество закрытых микрозаймов (заёмщик)'],
#        [128, 'other_closed',
#         'количество других закрытых кредитов (не авто, не ипотека, не карта, не потребительский кредит) (заёмщик)'],
#        [129, 'cl_closed_gr500k',
#         'количество закрытых потребительских кредитов с суммой обязательств >=500 000 рублей (заёмщик)'],
#        [130, 'cl_closed_gr100k',
#         'количество закрытых потребительских кредитов с суммой обязательств >=100 000 рублей (заёмщик)'],
#        [131, 'cl_closed_gr50k',
#         'количество закрытых потребительских кредитов с суммой обязательств >=50 000 рублей (заёмщик)'],
#        [132, 'cl_closed_ls50k',
#         'количество закрытых потребительских кредитов с суммой обязательств <50 000 рублей (заёмщик)'],
#        [133, 'length_bank',
#         'длительность кредитной истории в банке (мес.) - от даты открытия самого раннего договора до даты отчёта'],
#        [134, 'length_bank_total',
#         'совокупная длительность кредитной истории в банке: по закрытым договорам - от даты открытия до даты факт. закрытия (мес.), по открытым - от открытия до даты отчёта'],
#        [135, 'length_total',
#         'совокупная длительность кредитной истории в бки: по закрытым договорам - от даты открытия до даты факт. закрытия (мес.), по открытым - от открытия до даты отчёта'],
#        [136, 'avg_liab_sum_total',
#         'средняя переоцененная в рубли сумма обязательства по всем  договорам по данным бки и банка'],
#        [137, 'avg_liab_sum_total_open_agr',
#         'средняя переоцененная в рубли сумма обязательства по открытым договорам по данным бки и банка'],
#        [138, 'avg_liab_sum_total_closed_agr',
#         'средняя переоцененная в рубли сумма обязательства по закрытым договорам по данным бки и банка'],
#        [139, 'max_liab_sum_bank_open',
#         'максимальная переоцененная в рубли сумма обязательства по открытым договорам по данным банка'],
#        [140, 'max_liab_sum_bki_open',
#         'максимальная переоцененная в рубли сумма обязательства по открытым договорам по данным бки'],
#        [141, 'max_liab_sum_bank_closed',
#         'максимальная переоцененная в рубли сумма обязательства по закрытым договорам по данным банка'],
#        [142, 'max_liab_sum_bki_closed',
#         'максимальная переоцененная в рубли сумма обязательства по закрытым договорам по данным бки'],
#        [143, 'total_liab_sum_bank_open_agr',
#         'общая переоцененная в рубли сумма обязательства по открытым договорам по данным банка'],
#        [144, 'total_liab_sum_bki_open_agr',
#         'общая переоцененная в рубли сумма обязательства по открытым договорам по данным бки'],
#        [145, 'total_liab_sum_bank_closed_agr',
#         'общая переоцененная в рубли сумма обязательства по закрытым договорам по данным банка'],
#        [146, 'total_liab_sum_bki_closed_agr',
#         'общая переоцененная в рубли сумма обязательства по закрытым договорам по данным бки'],
#        [147, 'outstanding',
#         'суммарная оставшаяся непогашенная задолженность'],
#        [148, 'outstanding_open',
#         'суммарная оставшаяся непогашенная задолженность по открытым счетам'],
#        [149, 'avg_delinquent_debt_total',
#         'среднее значение переоцененной в рубли текущей просроченной задолженности по всем обязательствам'],
#        [150, 'curr_arrear_rur',
#         'сумма текущей просрочки в рублях на дату запроса (кроме договоров поручительства)'],
#        [151, 'utilization_avg', 'средняя утилизация по всем картам'],
#        [152, 'cnt_liability_types',
#         'количество разных типов обязательств'],
#        [153, 'total_curr_payment',
#         'суммарная текущая платежная нагрузка'],
#        [154, 'only_guarantees',
#         'если все обязательства клиента являются договорами поручительства, то 1, иначе 0'],
#        [155, 'cnt_inquiry_last1w',
#         'общее число запросов кредитной истории за последнюю неделю'],
#        [156, 'cnt_inquiry_last1m',
#         'общее число запросов кредитной истории за последний месяц'],
#        [157, 'cnt_inquiry_last3m',
#         'общее число запросов кредитной истории за последние 3 месяца'],
#        [158, 'cnt_inquiry_last6m',
#         'общее число запросов кредитной истории за последние 6 месяцев'],
#        [159, 'cre_date',
#         'дата запроса из cre, по которому производился расчет агрегатов'],
#        [160, 'total_curr_payment_rkk', 'текущий платёж ркк'],
#        [161, 'bank_liab_paym',
#         'общая сумма платежей по действующим на данный момент кредитам, по данным гпб, на текущий момент'],
#        [162, 'bki_liab_paym',
#         'общая сумма платежей по действующим на данный момент кредитам, по данным бки (исключая кредиты гпб), запрошенным на момент подачи анкеты'],
#        [163, 'bki_loan_lst_close_m_term',
#         'количество месяцев с момента закрытия последнего выданного кредита в бки'],
#        [164, 'bki_loan_till_lst_close_m_term',
#         'количество месяцев до планового погашения последнего выданного кредита в бки'],
#        [165, 'bank_loan_lst_close_m_term',
#         'количество месяцев с момента закрытия последнего выданного кредита в гпб'],
#        [166, 'bank_loan_till_lst_close_m_term',
#         'количество месяцев до планового погашения последнего выданного кредита в гпб'],
#        [167, 'bank_loan_lst_rate',
#         'процентная ставка по последнему кредиту в гпб'],
#        [168, 'bank_loan_fst_rate',
#         'процентная ставка по первому кредиту в гпб'],
#        [169, 'bank_ki_flg',
#         'флаг наличия найденной ки в банке на отчетную дату'],
#        [170, 'max_paym_bank', 'максимальный ежемесячный платеж'],
#        [171, 'min_paym_bank', 'минимальный ежемесячный платеж'],
#        [172, 'max_paym_bank_act',
#         'максимальный ежемесячный платеж среди активных'],
#        [173, 'min_paym_bank_act',
#         'минимальный ежемесячный платеж среди активных'],
#        [174, 'bank_count_first_6m_1',
#         'наличие выхода на просрочку 1 день за последние 6м (данные банка)'],
#        [175, 'bank_count_first_6m_30',
#         'наличие выхода на просрочку 30 дней за последние 6м (данные банка)'],
#        [176, 'bank_count_first_6m_60',
#         'наличие выхода на просрочку 60 дней за последние 6м (данные банка)'],
#        [177, 'bank_count_first_6m_90',
#         'наличие выхода на просрочку 90 дней за последние 6м (данные банка)'],
#        [178, 'bank_count_first_12m_1',
#         'наличие выхода на просрочку 1 день за последние 12м (данные банка)'],
#        [179, 'bank_count_first_12m_30',
#         'наличие выхода на просрочку 30 дней за последние 12м (данные банка)'],
#        [180, 'bank_count_first_12m_60',
#         'наличие выхода на просрочку 60 дней за последние 12м (данные банка)'],
#        [181, 'bank_count_first_12m_90',
#         'наличие выхода на просрочку 90 дней за последние 12м (данные банка)'],
#        [182, 'first_payment_default', 'дефолт при первом платеже'],
#        [183, 'second_payment_default', 'дефолт при втором платеже'],
#        [184, 'age', 'возраст клиента (в годах) на дату расчета'],
#        [185, 'cnt_adv_repayment',
#         'количество договоров погашенных раньше даты планового завершения на 10 или более %'],
#        [186, 'cnt_adv_repayment_gr_500k',
#         'количество договоров погашенных раньше даты планового завершения на 10 или более % с суммой выдачи более 100 000 рублей'],
#        [187, 'cnt_adv_repayment_gr_100k',
#         'количество договоров погашенных раньше даты планового завершения на 10 или более % с суммой выдачи более 500 000 рублей'],
#        [188, 'cnt_adv_repayment_gr_50k',
#         'количество договоров погашенных раньше даты планового завершения на 10 или более % с суммой выдачи более 50 000 рублей'],
#        [189, 'cnt_adv_repayment_ls_50k',
#         'количество договоров погашенных раньше даты планового завершения на 10 или более % с суммой выдачи не более 50 000 рублей'],
#        [190, 'ratio_adv_repayment',
#         'доля договоров погашенных раньше даты планового завершения на 10 или более %'],
#        [191, 'ratio_adv_repayment_adv_gr_500k',
#         'доля договоров погашенных раньше даты планового завершения на 10 или более % с суммой выдачи более 100 000 рублей'],
#        [192, 'ratio_adv_repayment_adv_gr_100k',
#         'доля договоров погашенных раньше даты планового завершения на 10 или более % с суммой выдачи более 500 000 рублей'],
#        [193, 'ratio_adv_repayment_adv_gr_50k',
#         'доля договоров погашенных раньше даты планового завершения на 10 или более % с суммой выдачи более 50 000 рублей'],
#        [194, 'ratio_adv_repayment_adv_ls_50k',
#         'доля договоров погашенных раньше даты планового завершения на 10 или более % с суммой выдачи не более 50 000 рублей'],
#        [195, 'ratio_cl_closed',
#         'доля закрытых потребительских кредитов (заёмщик)'],
#        [196, 'ratio_cl_closed_gr500k',
#         'доля закрытых потребительских кредитов с суммой обязательств >=100 000 рублей (заёмщик)'],
#        [197, 'ratio_cl_closed_gr100k',
#         'доля закрытых потребительских кредитов с суммой обязательств >=500 000 рублей (заёмщик)'],
#        [198, 'ratio_cl_closed_gr50k',
#         'доля закрытых потребительских кредитов с суммой обязательств >=50 000 рублей (заёмщик)'],
#        [199, 'ratio_cl_closed_ls50k',
#         'доля закрытых потребительских кредитов с суммой обязательств <50 000 рублей (заёмщик)'],
#        [200, 'avg_liab_sum_total_adv_agr',
#         'средняя сумма обязательства по всем  договорам по данным бки и банка, погашенная досрочно'],
#        [201, 'avg_diff_plan_fact_closed',
#         'средняя дельта по планируемой и фактической дате закрытия'],
#        [202, 'total_liab_sum_bank_adv_agr',
#         'общая переоцененная в рубли сумма обязательства по договорам по данным банка'],
#        [203, 'total_liab_sum_bki_adv_agr',
#         'общая переоцененная в рубли сумма обязательства по договорам по данным бки'],
#        [204, 'cnt_adv25_closed',
#         'количество досрочной закрытых договоров более 25тр'],
#        [205, 'total_liab_sum_bank_adv25_agr',
#         'сумма досрочной закрытых договоров более 25тр по данным банка'],
#        [206, 'total_liab_sum_bki_adv25_agr',
#         'сумма досрочной закрытых договоров более 25тр по данным бки'],
#        [207, 'curdel_0plus_bank',
#         'рассчитывается только для договоров, открытых в банке, без учёта договоров поручительства.\nколичество договоров с текущей просрочкой более 500 руб. и длительностью просрочки более 0 дней.'],
#        [208, 'curdel_0plus_bki',
#         'рассчитывается только для договоров, открытых в в других банках, без учёта договоров поручительства.\nколичество договоров с текущей просрочкой более 500 руб. и длительностью просрочки более 0 дней.'],
#        [209, 'curdel_30plus_bank',
#         'рассчитывается только для договоров, открытых в банке без учёта договоров поручительства.\nколичество договоров с текущей просрочкой более 500 руб. и длительностью просрочки более 30 дней.'],
#        [210, 'curdel_30plus_bki',
#         'рассчитывается только для договоров, открытых в в других банках, без учёта договоров поручительства.\nколичество договоров с текущей просрочкой более 500 руб. и длительностью просрочки более 30 дней.'],
#        [211, 'curdel_60plus_bank',
#         'рассчитывается только для договоров, открытых в банке без учёта договоров поручительства.\nколичество договоров с текущей просрочкой более 500 руб. и длительностью просрочки более 60 дней.'],
#        [212, 'curdel_60plus_bki',
#         'рассчитывается только для договоров, открытых в в других банках, без учёта договоров поручительства.\nколичество договоров с текущей просрочкой более 500 руб. и длительностью просрочки более 60 дней.'],
#        [213, 'curdel_tech_bank',
#         'рассчитывается только для договоров, открытых в банке без учёта договоров поручительства.\nопределяется количество договоров с текущей просрочкой >0 и <500 руб. и длительностью просрочки более 0 дней.'],
#        [214, 'curdel_tech_bki',
#         'рассчитывается только для договоров, открытых в в других банках без учёта договоров поручительства.\nопределяется количество договоров с текущей просрочкой >0 и <500 руб. и длительностью просрочки более 0 дней.'],
#        [215, 'bank_1_29_5y_debtor',
#         'общее число просрочек до 29 дней в банке за 5 лет'],
#        [216, 'bank_30_59_5y_debtor',
#         'общее число просрочек от 30 до 59 дней в банке за 5 лет'],
#        [217, 'bank_60_89_5y_debtor',
#         'общее число просрочек от 60 до 89 дней в банке за 5 лет'],
#        [218, 'bank_90_119_5y_debtor',
#         'общее число просрочек от 90 до 119 дней в банке за 5 лет'],
#        [219, 'bank_120plus_5y_debtor',
#         'общее число просрочек от 120 дней в банке за 5 лет']],
#       dtype=object)

# %%
aggregates[['client_id','report_date','cl_open','cl_closed']]\
            [(aggregates.cnt_opened == 0) & (aggregates.cnt_closed == 0)]
# Out:
#         client_id          report_date  cl_open  cl_closed
# 21           8881  2019-11-01 00:00:00      0.0        0.0
# 237          5978  2019-11-01 00:00:00      0.0        0.0
# 346          7332  2019-11-01 00:00:00      0.0        0.0
# 599          6620  2019-11-01 00:00:00      0.0        0.0
# 764          9321  2019-02-01 00:00:00      0.0        0.0
# ...           ...                  ...      ...        ...
# 176813       2198  2019-05-01 00:00:00      0.0        0.0
# 176933       6620  2019-05-01 00:00:00      0.0        0.0
# 177053       4029  2020-02-01 00:00:00      0.0        0.0
# 177134       8881  2020-02-01 00:00:00      0.0        0.0
# 177614       4090  2020-02-01 00:00:00      0.0        0.0
#
# [682 rows x 4 columns]

# %% [markdown]
# ### Предобработка

# %%
df1 = aggregates.copy()
# Удаляем записи с нанами в cl_open и cl_closed
df1 = df1.drop(df1[df1['cl_open'].isnull()].index.values)
df1 = df1.drop(df1[df1['cl_closed'].isnull()].index.values)

df1 = df1.sort_values(by=['client_id', 'report_date'])

# %% [markdown]
# # Первый подход

# %% [markdown]
# Формируем таргет из двух фичей: cl_open и cl_closed - количество открытых и закрытых на данных момент потребительских кредитов.
# Cуммируем количество открытых на данный момент счетов и количество закрытых, чтобы получить суммарное кол-во счетов

# %%
df1 = df1.copy()
df1['cl_total'] = df1['cl_open'] + df1['cl_closed']

# %% [markdown]
# Смотрим, увеличилось ли количесвто открытых счетов в следующий месяц, и так для каждого месяца и клиента. Если увеличилось,
# записываем 1, если нет - 0.

# %%
df1['target'] = ((df1.cl_total.shift(-1) - df1.cl_total) > 0).astype(int)

# %%
# Удаляем последнюю запись каждого клиента, так как она не информативна
last_date = df1.drop_duplicates('client_id',keep='last')
df1 = df1.drop(last_date.index.values)

# %%
# классы
df1.target.value_counts()
# Out:
# 0    90734
# 1     4599
# Name: target, dtype: int64

# %%
# дропаем ненужные фичи
df1 = df1.drop(['cre_date'],axis=1)

# %% [markdown]
# ### Кодирование категориальных фичей

# %%
from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder(sparse=False)

# %%
# заменяем наны и пропуски на нули
df1.reset_index(inplace=True,drop=True)

df_slice = df1.select_dtypes(include=['object']).copy().iloc[:,1:]
df_slice.fillna(0,inplace=True)
df_slice.replace(' ',0,inplace=True)
df_slice = df_slice.astype(str)

# %%
# энкодим
df_slice_enc = pd.DataFrame(encoder.fit_transform(df_slice))
df1 = df1.drop(df_slice.columns.values,axis=1)
df1 = df1.join(df_slice_enc)

# %% [markdown]
# ### Кодирование report_date

# %%
df1['report_date'] = df1.report_date.astype('datetime64[ns]')

# %%
df1['dayofweek'] = df1['report_date'].dt.dayofweek
df1['quarter'] = df1['report_date'].dt.quarter
df1['month'] = df1['report_date'].dt.month
df1['year'] = df1['report_date'].dt.year
df1['weekofyear'] = df1['report_date'].dt.weekofyear

# %%
df1 = df1.sort_values(by='report_date')

# %% [markdown]
# ### Оставшиеся НаНы

# %%
# мода
# df1 = df1.fillna(df1.mode(dropna=True).iloc[0])

# %%
# медиана
df1 = df1.fillna(df1.mean())

# %%
# df1 = df1.fillna(0)

# %% [markdown]
# ### Строим модель

# %%
df1.reset_index(inplace=True,drop=True)

# %%
X = df1.drop(['target','client_id','report_date'], axis = 1)
y = df1.target

# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_validate
import xgboost as xgb
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression

from xgboost import plot_importance
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import recall_score, roc_auc_score, f1_score
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
# Делим на трейн и тест. Так как данные расположены во времени, то test - это 'будущее' трейна

tscv2 = TimeSeriesSplit(n_splits=2,test_size=int(X.shape[0]*0.2))
for train_index, test_index in tscv2.split(X):
    print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y.iloc[train_index], y.iloc[test_index]
# Out:
# TRAIN: [    0     1     2 ... 57198 57199 57200] TEST: [57201 57202 57203 ... 76264 76265 76266]
# TRAIN: [    0     1     2 ... 76264 76265 76266] TEST: [76267 76268 76269 ... 95330 95331 95332]

# %%
xgb_class = xgb.XGBClassifier(random_state  = SEED)
rf_class = RandomForestClassifier(random_state=SEED)

model = xgb_class

# %%
# Кросс валидация тоже должна учитывать, что данные расположены во времени
tscv = TimeSeriesSplit(5)
cross_validate(model, X_train, y_train, cv=tscv, scoring='f1', verbose=1)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:  2.1min finished
# {'fit_time': array([ 8.1433394 , 16.01381922, 24.46997094, 33.88486409, 42.65454531]),
#  'score_time': array([0.18489385, 0.19188952, 0.19288874, 0.2008853 , 0.19389009]),
#  'test_score': array([0.01530612, 0.        , 0.01196809, 0.08135422, 0.        ])}

# %%
model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred = (model.predict(X_test))
print('ROC AUC: ',roc_auc_score(y_test ,y_pred),
      '\nRecall:  ',recall_score(y_test ,y_pred),
      '\nF1 score:',f1_score(y_test ,y_pred))
# Out:
# ROC AUC:  0.5029231922369947
# Recall:   0.00715307582260372
# F1 score: 0.013736263736263736

# %%
ConfusionMatrixDisplay(confusion_matrix = confusion_matrix(y_test,y_pred)).plot()

# %%
plot_importance(xgb_class,max_num_features = 15)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# ### Вывод
# Модель - случайный классификатор ¯\_(ツ)_/¯ . Пробуем второй подход

# %% [markdown]
# # Подход 2

# %%
df2 = aggregates.copy()
df2 = df2.sort_values(by=['client_id', 'report_date'])

# %%
# данные за последний месяц
df_last_month = df2[df2.report_date >= '2020-10-01'].copy()

# %% [markdown]
# Итак, рассмотрим три фичи, из которых будем формировать таргет. Первые две это cl_open и cl_closed - количество открытых и закрытых на данных момент потребительских кредитов.

# %%
df_last_month['cl_open'].value_counts()
# Out:
# 0.0     4027
# 1.0     1377
# 2.0      542
# 3.0      163
# 4.0       87
# 5.0       17
# 6.0       12
# 7.0        6
# 8.0        3
# 12.0       2
# 9.0        1
# 10.0       1
# 14.0       1
# Name: cl_open, dtype: int64

# %%
df_last_month['cl_closed'].value_counts()
# Out:
# 0.0      2248
# 1.0       836
# 2.0       614
# 3.0       487
# 4.0       399
# 5.0       329
# 6.0       264
# 7.0       211
# 8.0       197
# 9.0       123
# 10.0      107
# 11.0      102
# 12.0       66
# 13.0       48
# 14.0       41
# 15.0       32
# 18.0       19
# 16.0       17
# 17.0       14
# 19.0       13
# 20.0       13
# 22.0       12
# 21.0        8
# 25.0        5
# 24.0        4
# 23.0        4
# 28.0        4
# 27.0        3
# 30.0        2
# 35.0        2
# 33.0        2
# 26.0        2
# 37.0        2
# 36.0        1
# 38.0        1
# 42.0        1
# 49.0        1
# 31.0        1
# 92.0        1
# 34.0        1
# 62.0        1
# 121.0       1
# Name: cl_closed, dtype: int64

# %%
fig,ax = plt.subplots(1,2,figsize=(15,5))
ax[0].hist(df_last_month['cl_open'],bins=100)
ax[0].grid()
ax[0].set(xlabel='cl_open')

ax[1].hist(df_last_month['cl_closed'],bins=100)
ax[1].grid()
ax[1].set(xlabel='cl_closed')
plt.show()
# Out:
# D:\Progi\Anaconda\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# D:\Progi\Anaconda\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# Из вывода и графиков видно, что cl_open > 6 можно рассматривать как выбросы, аналогично с cl_closed > 20

# %%
df_last_month = df_last_month.drop(df_last_month[df_last_month['cl_open']>5].index.values)
df_last_month = df_last_month.drop(df_last_month[df_last_month['cl_closed']>20].index.values)

# %% [markdown]
# Рассмотрим еще одну фичу: first_opened - время в месяцах, прошедшее с даты открытия самого раннего счёта

# %%
plt.hist(df_last_month['first_opened'],bins=100)
plt.xlabel('first_opened')
plt.grid()
plt.show()
# Out:
# D:\Progi\Anaconda\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# D:\Progi\Anaconda\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# Дата основания Газпромбанка 1990 год. То есть за 30 лет прошло  360 месяцев. first_opened > 360 - точно выбросы. Также имеет смысл удалить записи c временем, прошедшим с даты открытия самого раннего счёта меньше месяца, те first_opened < 1. Это обусловлено как тем, что так у метрики не будет очень больших значений, а также тем, что об этих людям мы мало чего знаем.

# %%
df_last_month = df_last_month.drop(df_last_month[(df_last_month['first_opened']>360) \
                                                 | (df_last_month['first_opened']<1)].index.values)

# %%
# есть еще 20 нанов, их можно удалить
df_last_month = df_last_month.drop(df_last_month[df_last_month['first_opened'].isnull()].index.values)
# также есть клиент, у которого first_opened = 0, тоже удаляем
df_last_month = df_last_month.drop(df_last_month[df_last_month['first_opened']==0].index.values)

# %% [markdown]
# Скорее всего это не все выбросы, но по крайней мере мы избавились от тех, что влияют на наш таргет

# %% [markdown]
# Итак, формируем таргет

# %%
# суммируем количество открытых на данный момент кредитов и количество закрытых, чтобы получить суммарное кол-во счетов
df_last_month['cl_total'] = df_last_month['cl_open'] + df_last_month['cl_closed']

# таргет - как часто клиент берет кредит: делим колчиество открытих потреб. кредитов на время в месяцах, 
# прошедшее с даты открытия первого  
df_last_month['target'] = df_last_month['cl_total'] / df_last_month['first_opened']

# %%
plt.hist(df_last_month['target'],bins=100)
plt.xlabel('target')
plt.grid()
plt.show()
# Out:
# D:\Progi\Anaconda\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# D:\Progi\Anaconda\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
plt.scatter([i for i in range(df_last_month.shape[0])],df_last_month['target'])
plt.grid()
plt.show()

# %% [markdown]
# Разделим таргет на два класса: первая - таргет больше среднего значения, вторая - меньше. Запишем как новый таргет

# %%
df_last_month['target'] = (df_last_month['target']>df_last_month['target'].mean()).astype(int)

# %%
df2_1 = df_last_month

# %% [markdown]
# ### Обработка, аналогичная первой модели

# %%
# дропаем ненужные фичи а также first_opened и cl_total
df2_1 = df2_1.drop(['cre_date','report_date','first_opened','cl_total'],axis=1)

# %%
encoder = OneHotEncoder(sparse=False)

# %%
# заменяем наны и пропуски на нули
df2_1.reset_index(inplace=True,drop=True)

df_slice = df2_1.select_dtypes(include=['object']).copy()
df_slice.fillna(0,inplace=True)
df_slice.replace(' ',0,inplace=True)
df_slice = df_slice.astype(str)

# %%
# энкодим
df_slice_enc = pd.DataFrame(encoder.fit_transform(df_slice))
df2_1 = df2_1.drop(df_slice.columns.values,axis=1)
df2_1.reset_index(inplace=True,drop=True)
df2_1 = df2_1.join(df_slice_enc)

# %%
df2_1 = df2_1.fillna(df2_1.mean())

# %% [markdown]
# ### Строим модель

# %%
X = df2_1.drop(['target','client_id'], axis = 1)
y = df2_1.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=SEED)

# %%
xgb_class = xgb.XGBClassifier(random_state  = SEED)
rf_class = RandomForestClassifier(random_state=SEED)
logreg = LogisticRegression()

model = xgb_class

# %%
cross_validate(model, X_train, y_train, cv=5, scoring='f1', verbose=1)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   20.0s finished
# {'fit_time': array([3.81481242, 3.90576077, 3.90576148, 3.6459105 , 4.64233875]),
#  'score_time': array([0.0279839 , 0.02698493, 0.02598476, 0.02798319, 0.04197598]),
#  'test_score': array([0.88      , 0.84939759, 0.84302326, 0.79651163, 0.79635258])}

# %%
model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred = (model.predict(X_test))
print('ROC AUC: ',roc_auc_score(y_test ,y_pred),
      '\nRecall:  ',recall_score(y_test ,y_pred),
      '\nF1 score:',f1_score(y_test ,y_pred))
# Out:
# ROC AUC:  0.8976864575608196
# Recall:   0.8189300411522634
# F1 score: 0.8257261410788382

# %%
ConfusionMatrixDisplay(confusion_matrix = confusion_matrix(y_test,y_pred)).plot()

# %%
plot_importance(xgb_class,max_num_features = 15)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# ### Добавим transactions

# %%
# есть выбросы, в которых средняя сумма слишком большая. Удаляем
transactions = transactions[transactions.att_sum_avg<100000]

# %%
plt.hist(transactions.att_sum_avg,bins=100)
plt.grid()
plt.show()

# %%
dummies = pd.get_dummies(transactions.mcc_group)
dummies = dummies * transactions.att_cnt.values.reshape(-1,1)
df_groups = transactions.client_id.to_frame().join(dummies)

# %%
df_groups = df_groups.groupby('client_id').sum().reset_index()

# %%
df3 = df2_1.merge(df_groups,on='client_id', how='inner')

# %% [markdown]
# ### Строим модель

# %%
X = df3.drop(['target','client_id'], axis = 1)
y = df3.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=SEED)

# %%
xgb_class = xgb.XGBClassifier(random_state  = SEED)
rf_class = RandomForestClassifier(random_state=SEED)
logreg = LogisticRegression()

model = xgb_class

# %%
cross_validate(model, X_train, y_train, cv=5, scoring='f1', verbose=1)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:   18.3s finished
# {'fit_time': array([3.59693718, 3.59593749, 3.62791896, 3.60793066, 3.82680678]),
#  'score_time': array([0.03098226, 0.02998328, 0.02898431, 0.02898312, 0.03098106]),
#  'test_score': array([0.81395349, 0.85310734, 0.85070423, 0.81948424, 0.81733746])}

# %%
model.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=100, n_jobs=0, num_parallel_tree=1, random_state=42,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_pred = (model.predict(X_test))
print('ROC AUC: ',roc_auc_score(y_test ,y_pred),
      '\nRecall:  ',recall_score(y_test ,y_pred),
      '\nF1 score:',f1_score(y_test ,y_pred))
# Out:
# ROC AUC:  0.890392382858905
# Recall:   0.8025751072961373
# F1 score: 0.8183807439824945

# %%
ConfusionMatrixDisplay(confusion_matrix = confusion_matrix(y_test,y_pred)).plot()

# %%
plot_importance(xgb_class,max_num_features = 15)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>
